# %%
import pandas as pd
import sqlite3
import numpy as np
import gzip
import json

# %%
def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF("Toys_and_Games_5.json.gz")

# %%
df.columns
# Out:
# Index(['overall', 'vote', 'verified', 'reviewTime', 'reviewerID', 'asin',
#        'style', 'reviewerName', 'reviewText', 'summary', 'unixReviewTime',
#        'image'],
#       dtype='object')

# %%
df
# Out:
#          overall vote  verified   reviewTime      reviewerID        asin  \
# 0            5.0    3      True   10 6, 2013  A2LSCFZM2FBZK7  0486427706
# 1            5.0    9      True   08 9, 2013  A3IXP5VS847GE5  0486427706
# 2            5.0  NaN      True   04 5, 2016  A1274GG1EB2JLJ  0486427706
# 3            5.0    3      True  02 13, 2016  A30X5EGBYAZQQK  0486427706
# 4            5.0  NaN      True  12 10, 2015  A3U6UNXLAUY6ZV  0486427706
# ...          ...  ...       ...          ...             ...         ...
# 1828966      5.0  NaN      True  01 19, 2018  A3RRY2TCWM3MWU  B01HJ4GZIU
# 1828967      1.0  NaN      True   10 2, 2017  A2ZRCFLXI8J39O  B01HJ4GZIU
# 1828968      5.0  NaN      True   10 5, 2018  A2IIP6L4PRAXVN  B01HJ8SCA0
# 1828969      5.0  NaN      True  08 12, 2018   ACJH8FKNLSXIQ  B01HJDFWDK
# 1828970      5.0  NaN      True   07 9, 2018   A2KVWRRMFOYCW  B01HJDFWDK
#
#                                     style                     reviewerName  \
# ...
