# %%
import pandas as pd

# %%
BlendDF = pd.read_csv('BlendedReviews.csv')

# %%
# The normal imports
import numpy as np
import pandas as pd

# modules and libraries
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
BlendDF.head()
# Out:
#                                          ReviewLemma  VaderCompound  Short  \
# 0  lol operation make itchy xd together fun opera...       4.952393      0
# 1                              world pokemon fantasy       2.999700      1
# 2  polish watery way color maybe fake dont know b...       2.046157      0
# 3                                 granddaughter love       4.143672      1
# 4  digital code way go quick easy right ordered g...       4.070861      0
#
#    Verified  Long  IsImage  WordCount  vote  LuxBea  VidGam  ...  Sadness  \
# 0         1     0        0         13     0       0       1  ...  17.4186
# 1         1     0        0          3     0       0       1  ...   2.7153
# 2         1     0        0         10     0       1       0  ...  10.1113
# 3         1     0        0          2     0       0       1  ...   2.6297
# 4         1     0        0         16     0       0       1  ...  14.8722
#
# ...

# %%
BlendDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62670 entries, 0 to 62669
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ReviewLemma    62670 non-null  object
#  1   VaderCompound  62670 non-null  float64
#  2   Short          62670 non-null  int64
#  3   Verified       62670 non-null  int64
#  4   Long           62670 non-null  int64
#  5   IsImage        62670 non-null  int64
#  6   WordCount      62670 non-null  int64
#  7   vote           62670 non-null  int64
#  8   LuxBea         62670 non-null  int64
#  9   VidGam         62670 non-null  int64
#  10  Joy            62670 non-null  float64
#  11  Anger          62670 non-null  float64
#  12  Sadness        62670 non-null  float64
#  13  Fear           62670 non-null  float64
#  14  Disgust        62670 non-null  float64
#  15  overall        62670 non-null  int64
#  16  BinaryRating   62670 non-null  int64
# ...

# %%
BlendDF.describe()
# Out:
#        VaderCompound         Short      Verified          Long       IsImage  \
# count   62670.000000  62670.000000  62670.000000  62670.000000  62670.000000
# mean        4.006059      0.276129      0.782703      0.297942      0.011074
# std         1.006586      0.447085      0.412410      0.457357      0.104649
# min         1.000000      0.000000      0.000000      0.000000      0.000000
# 25%         3.546182      0.000000      1.000000      0.000000      0.000000
# 50%         4.319298      0.000000      1.000000      0.000000      0.000000
# 75%         4.784968      1.000000      1.000000      1.000000      0.000000
# max         5.000000      1.000000      1.000000      1.000000      1.000000
#
#           WordCount          vote        LuxBea        VidGam           Joy  \
# count  62670.000000  62670.000000  62670.000000  62670.000000  62670.000000
# mean      35.361656      1.445093      0.182990      0.817010     57.360644
# ...

# %%
BlendDF.hist(figsize=(20,15)) # Histogram for all features
# Out:
# array([[<AxesSubplot:title={'center':'VaderCompound'}>,
#         <AxesSubplot:title={'center':'Short'}>,
#         <AxesSubplot:title={'center':'Verified'}>,
#         <AxesSubplot:title={'center':'Long'}>,
#         <AxesSubplot:title={'center':'IsImage'}>],
#        [<AxesSubplot:title={'center':'WordCount'}>,
#         <AxesSubplot:title={'center':'vote'}>,
#         <AxesSubplot:title={'center':'LuxBea'}>,
#         <AxesSubplot:title={'center':'VidGam'}>,
#         <AxesSubplot:title={'center':'Joy'}>],
#        [<AxesSubplot:title={'center':'Anger'}>,
#         <AxesSubplot:title={'center':'Sadness'}>,
#         <AxesSubplot:title={'center':'Fear'}>,
#         <AxesSubplot:title={'center':'Disgust'}>,
#         <AxesSubplot:title={'center':'overall'}>],
#        [<AxesSubplot:title={'center':'BinaryRating'}>,
#         <AxesSubplot:title={'center':'AvgJoy'}>,
#         <AxesSubplot:title={'center':'AvgAnger'}>,
#         <AxesSubplot:title={'center':'AvgSadness'}>,
# ...

# %%
#find any possible correlation and map it 
total = BlendDF.corr()
plt.figure(figsize =(20,10))
sns.heatmap(total, cmap = 'RdBu', annot = True)
# Out:
# <AxesSubplot:>

# %%
#boxplot for Vader v Overall
plt.figure(figsize=(12,6))
v = sns.boxplot(x='overall',y='VaderCompound',data=BlendDF, palette = "crest")
v.set_title('VADER Score and Overall Rating Boxplot')
# Out:
# Text(0.5, 1.0, 'VADER Score and Overall Rating Boxplot')

# %%
# Boxplot for Vader v Binary 
plt.figure(figsize=(12,6))
v1 = sns.boxplot(x='BinaryRating',y='VaderCompound',data=BlendDF, palette = "rocket")
v1.set_title('VADER Score and Binary Rating Boxplot')
# Out:
# Text(0.5, 1.0, 'VADER Score and Binary Rating Boxplot')

# %%
plt.figure(figsize=(12,6))
aj =sns.boxplot(x='overall',y='AvgJoy',data=BlendDF, palette = "crest")
aj.set_title('Average Joy Score and Overall Rating Boxplot')
# Out:
# Text(0.5, 1.0, 'Average Joy Score and Overall Rating Boxplot')

# %%
plt.figure(figsize=(12,6))
aa = sns.boxplot(x='overall',y='AvgAnger',data=BlendDF, palette = "crest")
aa.set_title('Average Anger Score and Overall Rating Boxplot')
# Out:
# Text(0.5, 1.0, 'Average Anger Score and Overall Rating Boxplot')

# %%
plt.figure(figsize=(12,6))
ad = sns.boxplot(x='overall',y='AvgSadness',data=BlendDF, palette = "crest")
ad.set_title('Average Sadness Score and Overall Rating Boxplot')
# Out:
# Text(0.5, 1.0, 'Average Sadness Score and Overall Rating Boxplot')

# %%
plt.figure(figsize=(12,6))
af = sns.boxplot(x='overall',y='AvgFear',data=BlendDF,palette = "crest")
af.set_title('Average Fear Score and Overall Rating Boxplot')
# Out:
# Text(0.5, 1.0, 'Average Fear Score and Overall Rating Boxplot')

# %%
plt.figure(figsize=(12,6))
ai = sns.boxplot(x='overall',y='AvgDisgust',data=BlendDF, palette = "crest")
ai.set_title('Average Disgust Score and Overall Rating Boxplot')
# Out:
# Text(0.5, 1.0, 'Average Disgust Score and Overall Rating Boxplot')

# %%
plt.figure(figsize=(12,6))
yy = sns.boxplot(x='BinaryRating',y='AvgJoy',data=BlendDF,palette = "rocket")
yy.set_title('Average Joy Score and Binary Rating Boxplot')
# Out:
# Text(0.5, 1.0, 'Average Joy Score and Binary Rating Boxplot')

# %%
plt.figure(figsize=(12,6))
nn = sns.boxplot(x='BinaryRating',y='AvgAnger',data=BlendDF, palette = "rocket")
nn.set_title('Average Anger Score and Binary Rating Boxplot')
# Out:
# Text(0.5, 1.0, 'Average Anger Score and Binary Rating Boxplot')

# %%
plt.figure(figsize=(12,6))
ii = sns.boxplot(x='BinaryRating',y='AvgFear',data=BlendDF, palette = "rocket")
ii.set_title('Average Fear Score and Binary Rating Boxplot')
# Out:
# Text(0.5, 1.0, 'Average Fear Score and Binary Rating Boxplot')

# %%
plt.figure(figsize=(12,6))
ss = sns.boxplot(x='BinaryRating',y='AvgSadness',data=BlendDF, palette = "rocket")
ss.set_title('Average Sadness Score and Binary Rating Boxplot')
# Out:
# Text(0.5, 1.0, 'Average Sadness Score and Binary Rating Boxplot')

# %%
plt.figure(figsize=(12,6))
dd = sns.boxplot(x='BinaryRating',y='AvgDisgust',data=BlendDF, palette = "rocket")
dd.set_title('Average Disgust Score and Binary Rating Boxplot')
# Out:
# Text(0.5, 1.0, 'Average Disgust Score and Binary Rating Boxplot')

# %%
# Can also use hex bins for a more concise picture
e = sns.jointplot(BlendDF['AvgFear'],BlendDF['AvgSadness'],kind='hex', color = 'g' )
e.fig.suptitle("Distribution and Scatter Plot of the Average Score of Sadness and Fear")
e.fig.tight_layout()
# Out:
# D:\Anaconda 2\envs\DSC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
o = sns.jointplot(BlendDF['AvgJoy'],BlendDF['VaderCompound'], kind='hex', color = 'g' )
o.fig.suptitle("Distribution and Scatter Plot of VADER score and Average Score of Joy")
o.fig.tight_layout()
# Out:
# D:\Anaconda 2\envs\DSC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))
dataset=BlendDF['VaderCompound']
p = sns.distplot(dataset,bins=25,
             kde_kws={'color':'indianred','label':'KDE PLOT'},
             hist_kws={'color':'pink','label':"HISTOGRAM"},)
p.set_title("Distribution of VADER Score")
# Out:
# D:\Anaconda 2\envs\DSC\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of VADER Score')

# %%
plt.figure(figsize=(12,6))
dataset=BlendDF['AvgJoy']
q =sns.distplot(dataset,bins=25,
             kde_kws={'color':'indianred','label':'KDE PLOT'},
             hist_kws={'color':'pink','label':"HISTOGRAM"})
q.set_title("Distribution of Average Joy Score")
# Out:
# D:\Anaconda 2\envs\DSC\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Average Joy Score')

# %%
plt.figure(figsize=(12,6))
dataset=BlendDF['AvgFear']
b = sns.distplot(dataset,bins=25,
             kde_kws={'color':'indianred','label':'KDE PLOT'},
             hist_kws={'color':'pink','label':"HISTOGRAM"})
b.set_title("Distribution of Average Fear Score")
# Out:
# D:\Anaconda 2\envs\DSC\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Average Fear Score')

# %%
plt.figure(figsize=(12,6))
dataset=BlendDF['AvgDisgust']
f = sns.distplot(dataset,bins=25,
             kde_kws={'color':'indianred','label':'KDE PLOT'},
             hist_kws={'color':'pink','label':"HISTOGRAM"})
f.set_title("Distribution of Average Disgust Score")
# Out:
# D:\Anaconda 2\envs\DSC\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Average Disgust Score')

# %%
sns.violinplot(BlendDF['AvgJoy'])
# Out:
# D:\Anaconda 2\envs\DSC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AvgJoy'>

# %%
sns.violinplot(BlendDF['VaderCompound'])
# Out:
# D:\Anaconda 2\envs\DSC\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='VaderCompound'>

# %%
sns.regplot(x='Verified', y='Long', data=BlendDF, scatter = False)
# Out:
# <AxesSubplot:xlabel='Verified', ylabel='Long'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,15))
fig, axs = plt.subplots(ncols=5)
j  = sns.regplot(x=BlendDF['AvgJoy'], y=BlendDF['overall'], data=BlendDF, ax=axs[0], scatter = False, color = 'm')
s =sns.regplot(x=BlendDF['AvgSadness'], y=BlendDF['overall'], data=BlendDF, ax=axs[1], scatter = False, color = 'r')
a =sns.regplot(x=BlendDF['AvgAnger'], y=BlendDF['overall'], data=BlendDF, ax=axs[2], scatter = False, color = 'g')
d = sns.regplot(x=BlendDF['AvgDisgust'], y=BlendDF['overall'], data=BlendDF, ax=axs[3], scatter = False, color = 'b')
f = sns.regplot(x=BlendDF['AvgFear'], y=BlendDF['overall'], data=BlendDF, ax=axs[4], scatter = False, color = 'c')
j.set(ylim=(0, 5))
s.set(ylim=(0, 5))
a.set(ylim=(0, 5))
d.set(ylim=(0, 5))
f.set(ylim=(0, 5))
fig.suptitle ("Linear Relationship of the 5 different Average Emotions Scores and Overall Ratings")
# Out:
# Text(0.5, 0.98, 'Linear Relationship of the 5 different Average Emotions Scores and Overall Ratings')

# %%
plt.figure(figsize=(12,10))
fig, axs = plt.subplots(ncols=5)
j  = sns.regplot(x=BlendDF['AvgJoy'], y=BlendDF['BinaryRating'], data=BlendDF, ax=axs[0], scatter = False, color = 'm')
s =sns.regplot(x=BlendDF['AvgSadness'], y=BlendDF['BinaryRating'], data=BlendDF, ax=axs[1], scatter = False, color = 'r')
a =sns.regplot(x=BlendDF['AvgAnger'], y=BlendDF['BinaryRating'], data=BlendDF, ax=axs[2], scatter = False, color = 'g')
d = sns.regplot(x=BlendDF['AvgDisgust'], y=BlendDF['BinaryRating'], data=BlendDF, ax=axs[3], scatter = False, color = 'b')
f = sns.regplot(x=BlendDF['AvgFear'], y=BlendDF['BinaryRating'], data=BlendDF, ax=axs[4], scatter = False, color = 'c')
j.set(ylim=(0, 1))
s.set(ylim=(0, 1))
a.set(ylim=(0, 1))
d.set(ylim=(0, 1))
f.set(ylim=(0, 1))
fig.suptitle ("Linear Relationship of the 5 different Average Emotions and Binary Rating")
# Out:
# Text(0.5, 0.98, 'Linear Relationship of the 5 different Average Emotions and Binary Rating')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,6))
fig, axs = plt.subplots(ncols=5)
j  = sns.regplot(x=BlendDF['Joy'], y=BlendDF['overall'], data=BlendDF, ax=axs[0], scatter = False, color = 'm')
s =sns.regplot(x=BlendDF['Sadness'], y=BlendDF['overall'], data=BlendDF, ax=axs[1], scatter = False, color = 'r')
a =sns.regplot(x=BlendDF['Anger'], y=BlendDF['overall'], data=BlendDF, ax=axs[2], scatter = False, color = 'g')
d = sns.regplot(x=BlendDF['Disgust'], y=BlendDF['overall'], data=BlendDF, ax=axs[3], scatter = False, color ='b')
f = sns.regplot(x=BlendDF['Fear'], y=BlendDF['overall'], data=BlendDF, ax=axs[4], scatter = False, color ='c')
j.set(ylim=(0, 5))
s.set(ylim=(0, 5))
a.set(ylim=(0, 5))
d.set(ylim=(0, 5))
f.set(ylim=(0, 5))
fig.suptitle ("Linear Relationship of the 5 Different Total Emotion Scores and Overall Ratings")
# Out:
# Text(0.5, 0.98, 'Linear Relationship of the 5 Different Total Emotion Scores and Overall Ratings')

# %%
plt.figure(figsize=(12,10))
fig, axs = plt.subplots(ncols=5)
j  = sns.regplot(x=BlendDF['Joy'], y=BlendDF['BinaryRating'], data=BlendDF, ax=axs[0], scatter = False, color = 'm')
s =sns.regplot(x=BlendDF['Sadness'], y=BlendDF['BinaryRating'], data=BlendDF, ax=axs[1], scatter = False, color = 'r')
a =sns.regplot(x=BlendDF['Anger'], y=BlendDF['BinaryRating'], data=BlendDF, ax=axs[2], scatter = False, color = 'g')
d = sns.regplot(x=BlendDF['Disgust'], y=BlendDF['BinaryRating'], data=BlendDF, ax=axs[3], scatter = False, color = 'b')
f = sns.regplot(x=BlendDF['Fear'], y=BlendDF['BinaryRating'], data=BlendDF, ax=axs[4], scatter = False, color = 'c')
j.set(ylim=(0, 1))
s.set(ylim=(0, 1))
a.set(ylim=(0, 1))
d.set(ylim=(0, 1))
f.set(ylim=(0, 1))
fig.suptitle ("Linear Relationship of the 5 different Total Emotions and Overall Ratings")
# Out:
# [(0.0, 1.0)]

# %%
plt.figure(figsize=(12,10))
fig, axs = plt.subplots(ncols=2)
j  = sns.regplot(x=BlendDF['VaderCompound'], y=BlendDF['overall'], data=BlendDF, ax=axs[0], scatter = False, color = 'c')
s =sns.regplot(x=BlendDF['VaderCompound'], y=BlendDF['BinaryRating'], data=BlendDF, ax=axs[1], scatter = False)

j.set(ylim=(0, 5))
s.set(ylim=(0, 1))
fig.suptitle ("Linear Relationship of VADER Score with Overall and Binary Ratings")
# Out:
# Text(0.5, 0.98, 'Linear Relationship of VADER Score with Overall and Binary Ratings')

# %%
#move to EDA! 
from yellowbrick.features import rank1d, rank2d
X = BlendDF[['VaderCompound', 'Short', 'Verified', 'Long', 'IsImage',
       'WordCount', 'vote', 'LuxBea', 'VidGam', 'Joy', 'Anger', 'Sadness',
       'Fear', 'Disgust', 'overall', 'BinaryRating', 'AvgJoy', 'AvgAnger',
       'AvgSadness', 'AvgFear', 'AvgDisgust']]
_, axes = plt.subplots(ncols=2, figsize=(8,4))

rank1d(X, ax=axes[0], show=False)
rank2d(X, ax=axes[1], show=False)
plt.show()
plt.figure(figsize=(12,15))

# %%
from yellowbrick.features.radviz import radviz

#Load the classification dataset
X = BlendDF[['VaderCompound', 'Short', 'Verified', 'Long', 'IsImage',
       'WordCount', 'vote', 'LuxBea', 'VidGam', 'Joy', 'Anger', 'Sadness',
       'Fear', 'Disgust','AvgJoy', 'AvgAnger',
       'AvgSadness', 'AvgFear', 'AvgDisgust']]

Y = BlendDF['BinaryRating']



# Instantiate the visualizer
radviz(X, Y)
# Out:
# RadialVisualizer(ax=<AxesSubplot:title={'center':'RadViz for 19 Features'}>)

# %%
from yellowbrick.features.radviz import radviz

#Load the classification dataset
X = BlendDF[['VaderCompound', 'Short', 'Verified', 'Long', 'IsImage',
       'WordCount', 'vote', 'LuxBea', 'VidGam', 'Joy', 'Anger', 'Sadness',
       'Fear', 'Disgust','AvgJoy', 'AvgAnger',
       'AvgSadness', 'AvgFear', 'AvgDisgust']]

Y = BlendDF['overall']

# Instantiate the visualizer
radviz(X, Y)
# Out:
# RadialVisualizer(ax=<AxesSubplot:title={'center':'RadViz for 19 Features'}>)

# %%
from yellowbrick.features.radviz import radviz

#Load the classification dataset
X = BlendDF[['VaderCompound','AvgJoy']]

Y = BlendDF['BinaryRating']



# Instantiate the visualizer
radviz(X, Y)
# Out:
# RadialVisualizer(ax=<AxesSubplot:title={'center':'RadViz for 2 Features'}>)

# %%
from yellowbrick.features.radviz import radviz

#Load the classification dataset
X = BlendDF[['VaderCompound','AvgJoy']]

Y = BlendDF['overall']



# Instantiate the visualizer
radviz(X, Y)
# Out:
# RadialVisualizer(ax=<AxesSubplot:title={'center':'RadViz for 2 Features'}>)

# %%
from yellowbrick.features.radviz import radviz

#Load the classification dataset
X = BlendDF[['VaderCompound','Joy']]

Y = BlendDF['BinaryRating']

# Instantiate the visualizer
radviz(X, Y)
# Out:
# RadialVisualizer(ax=<AxesSubplot:title={'center':'RadViz for 2 Features'}>)
